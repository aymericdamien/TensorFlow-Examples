# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''
# Out:
# '\nA Convolutional Network implementation example using TensorFlow library.\nThis example is using the MNIST database of handwritten digits\n(http://yann.lecun.com/exdb/mnist/)\n\nAuthor: Aymeric Damien\nProject: https://github.com/aymericdamien/TensorFlow-Examples/\n'

# %%
import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print ("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print ("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print( "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 20331.203125, Training Accuracy= 0.27344
# Iter 2560, Minibatch Loss= 9887.432617, Training Accuracy= 0.46875
# Iter 3840, Minibatch Loss= 7949.569336, Training Accuracy= 0.59375
# Iter 5120, Minibatch Loss= 4632.485352, Training Accuracy= 0.75000
# Iter 6400, Minibatch Loss= 4025.208496, Training Accuracy= 0.76562
# Iter 7680, Minibatch Loss= 5617.732910, Training Accuracy= 0.71094
# Iter 8960, Minibatch Loss= 3444.596924, Training Accuracy= 0.78906
# Iter 10240, Minibatch Loss= 2649.995117, Training Accuracy= 0.85938
# Iter 11520, Minibatch Loss= 1728.382812, Training Accuracy= 0.89062
# Iter 12800, Minibatch Loss= 3180.599854, Training Accuracy= 0.82812
# Iter 14080, Minibatch Loss= 1311.604370, Training Accuracy= 0.89062
# Iter 15360, Minibatch Loss= 1476.999512, Training Accuracy= 0.91406
# Iter 16640, Minibatch Loss= 2655.782227, Training Accuracy= 0.89062
# Iter 17920, Minibatch Loss= 1281.013794, Training Accuracy= 0.87500
# Iter 19200, Minibatch Loss= 571.615051, Training Accuracy= 0.95312
# Iter 20480, Minibatch Loss= 248.693970, Training Accuracy= 0.94531
# Iter 21760, Minibatch Loss= 2633.039551, Training Accuracy= 0.85156
# Iter 23040, Minibatch Loss= 780.905396, Training Accuracy= 0.95312
# Iter 24320, Minibatch Loss= 1709.614624, Training Accuracy= 0.88281
# Iter 25600, Minibatch Loss= 795.303223, Training Accuracy= 0.89844
# Iter 26880, Minibatch Loss= 835.415161, Training Accuracy= 0.92188
# Iter 28160, Minibatch Loss= 1078.104370, Training Accuracy= 0.92188
# Iter 29440, Minibatch Loss= 1427.212646, Training Accuracy= 0.92188
# Iter 30720, Minibatch Loss= 644.050415, Training Accuracy= 0.91406
# Iter 32000, Minibatch Loss= 891.522522, Training Accuracy= 0.95312
# Iter 33280, Minibatch Loss= 433.270660, Training Accuracy= 0.95312
# Iter 34560, Minibatch Loss= 328.443176, Training Accuracy= 0.93750
# Iter 35840, Minibatch Loss= 211.973801, Training Accuracy= 0.97656
# Iter 37120, Minibatch Loss= 1249.736084, Training Accuracy= 0.92969
# Iter 38400, Minibatch Loss= 272.767578, Training Accuracy= 0.96094
# Iter 39680, Minibatch Loss= 332.344971, Training Accuracy= 0.95312
# Iter 40960, Minibatch Loss= 2008.566162, Training Accuracy= 0.85938
# Iter 42240, Minibatch Loss= 939.278442, Training Accuracy= 0.93750
# Iter 43520, Minibatch Loss= 585.671509, Training Accuracy= 0.95312
# Iter 44800, Minibatch Loss= 399.109650, Training Accuracy= 0.96094
# Iter 46080, Minibatch Loss= 273.329468, Training Accuracy= 0.98438
# Iter 47360, Minibatch Loss= 1255.834961, Training Accuracy= 0.91406
# Iter 48640, Minibatch Loss= 1224.617554, Training Accuracy= 0.92188
# Iter 49920, Minibatch Loss= 492.136719, Training Accuracy= 0.93750
# Iter 51200, Minibatch Loss= 413.174866, Training Accuracy= 0.92188
# Iter 52480, Minibatch Loss= 64.106995, Training Accuracy= 0.98438
# Iter 53760, Minibatch Loss= 139.564575, Training Accuracy= 0.98438
# Iter 55040, Minibatch Loss= 938.720825, Training Accuracy= 0.91406
# Iter 56320, Minibatch Loss= 842.276184, Training Accuracy= 0.93750
# Iter 57600, Minibatch Loss= 1219.829712, Training Accuracy= 0.92188
# Iter 58880, Minibatch Loss= 1041.359985, Training Accuracy= 0.91406
# Iter 60160, Minibatch Loss= 347.039215, Training Accuracy= 0.95312
# Iter 61440, Minibatch Loss= 695.624573, Training Accuracy= 0.93750
# Iter 62720, Minibatch Loss= 298.211670, Training Accuracy= 0.95312
# Iter 64000, Minibatch Loss= 385.648529, Training Accuracy= 0.94531
# Iter 65280, Minibatch Loss= 516.126892, Training Accuracy= 0.93750
# Iter 66560, Minibatch Loss= 521.727844, Training Accuracy= 0.96875
# Iter 67840, Minibatch Loss= 495.521698, Training Accuracy= 0.94531
# Iter 69120, Minibatch Loss= 169.013336, Training Accuracy= 0.98438
# Iter 70400, Minibatch Loss= 117.086159, Training Accuracy= 0.97656
# Iter 71680, Minibatch Loss= 630.205322, Training Accuracy= 0.94531
# Iter 72960, Minibatch Loss= 54.003571, Training Accuracy= 0.98438
# Iter 74240, Minibatch Loss= 504.967316, Training Accuracy= 0.96094
# Iter 75520, Minibatch Loss= 419.223389, Training Accuracy= 0.95312
# Iter 76800, Minibatch Loss= 933.053711, Training Accuracy= 0.92969
# Iter 78080, Minibatch Loss= 772.975464, Training Accuracy= 0.93750
# Iter 79360, Minibatch Loss= 661.421143, Training Accuracy= 0.94531
# Iter 80640, Minibatch Loss= 777.588806, Training Accuracy= 0.95312
# Iter 81920, Minibatch Loss= 438.026276, Training Accuracy= 0.94531
# Iter 83200, Minibatch Loss= 203.845093, Training Accuracy= 0.96094
# Iter 84480, Minibatch Loss= 589.076050, Training Accuracy= 0.93750
# Iter 85760, Minibatch Loss= 291.777924, Training Accuracy= 0.96094
# Iter 87040, Minibatch Loss= 298.182068, Training Accuracy= 0.96094
# Iter 88320, Minibatch Loss= 802.377441, Training Accuracy= 0.94531
# Iter 89600, Minibatch Loss= 273.291748, Training Accuracy= 0.96875
# Iter 90880, Minibatch Loss= 69.019798, Training Accuracy= 0.97656
# Iter 92160, Minibatch Loss= 491.734436, Training Accuracy= 0.96094
# Iter 93440, Minibatch Loss= 626.884644, Training Accuracy= 0.93750
# Iter 94720, Minibatch Loss= 628.266418, Training Accuracy= 0.95312
# Iter 96000, Minibatch Loss= 559.314941, Training Accuracy= 0.94531
# Iter 97280, Minibatch Loss= 71.681389, Training Accuracy= 0.98438
# Iter 98560, Minibatch Loss= 77.946976, Training Accuracy= 0.99219
# Iter 99840, Minibatch Loss= 611.479858, Training Accuracy= 0.92969
# Iter 101120, Minibatch Loss= 625.561279, Training Accuracy= 0.95312
# Iter 102400, Minibatch Loss= 491.794037, Training Accuracy= 0.94531
# Iter 103680, Minibatch Loss= 199.908905, Training Accuracy= 0.96875
# Iter 104960, Minibatch Loss= 251.356171, Training Accuracy= 0.95312
# Iter 106240, Minibatch Loss= 88.118210, Training Accuracy= 0.98438
# Iter 107520, Minibatch Loss= 490.014404, Training Accuracy= 0.96094
# Iter 108800, Minibatch Loss= 15.699799, Training Accuracy= 0.99219
# Iter 110080, Minibatch Loss= 82.532486, Training Accuracy= 0.96875
# Iter 111360, Minibatch Loss= 24.156029, Training Accuracy= 0.98438
# Iter 112640, Minibatch Loss= 182.506577, Training Accuracy= 0.96875
# Iter 113920, Minibatch Loss= 388.116516, Training Accuracy= 0.95312
# Iter 115200, Minibatch Loss= 163.603119, Training Accuracy= 0.97656
# Iter 116480, Minibatch Loss= 112.937271, Training Accuracy= 0.97656
# Iter 117760, Minibatch Loss= 164.268677, Training Accuracy= 0.96875
# Iter 119040, Minibatch Loss= 109.471817, Training Accuracy= 0.99219
# Iter 120320, Minibatch Loss= 425.706238, Training Accuracy= 0.96094
# Iter 121600, Minibatch Loss= 658.864136, Training Accuracy= 0.96094
# Iter 122880, Minibatch Loss= 82.793221, Training Accuracy= 0.96875
# Iter 124160, Minibatch Loss= 117.212708, Training Accuracy= 0.96875
# Iter 125440, Minibatch Loss= 526.778442, Training Accuracy= 0.90625
# Iter 126720, Minibatch Loss= 356.406433, Training Accuracy= 0.96875
# Iter 128000, Minibatch Loss= 226.477417, Training Accuracy= 0.95312
# Iter 129280, Minibatch Loss= 232.909836, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 5.187805, Training Accuracy= 0.99219
# Iter 131840, Minibatch Loss= 326.119537, Training Accuracy= 0.96875
# Iter 133120, Minibatch Loss= 113.714165, Training Accuracy= 0.96875
# Iter 134400, Minibatch Loss= 316.583801, Training Accuracy= 0.95312
# Iter 135680, Minibatch Loss= 440.264008, Training Accuracy= 0.96094
# Iter 136960, Minibatch Loss= 258.634491, Training Accuracy= 0.94531
# Iter 138240, Minibatch Loss= 5.964172, Training Accuracy= 0.99219
# Iter 139520, Minibatch Loss= 423.388855, Training Accuracy= 0.96875
# Iter 140800, Minibatch Loss= 197.606934, Training Accuracy= 0.94531
# Iter 142080, Minibatch Loss= 99.650047, Training Accuracy= 0.97656
# Iter 143360, Minibatch Loss= 181.789856, Training Accuracy= 0.97656
# Iter 144640, Minibatch Loss= 105.577538, Training Accuracy= 0.96875
# Iter 145920, Minibatch Loss= 58.147064, Training Accuracy= 0.98438
# Iter 147200, Minibatch Loss= 240.778839, Training Accuracy= 0.96094
# Iter 148480, Minibatch Loss= 4.314667, Training Accuracy= 0.99219
# Iter 149760, Minibatch Loss= 404.915588, Training Accuracy= 0.96875
# Iter 151040, Minibatch Loss= 287.287354, Training Accuracy= 0.94531
# Iter 152320, Minibatch Loss= 43.707199, Training Accuracy= 0.97656
# Iter 153600, Minibatch Loss= 116.748116, Training Accuracy= 0.96875
# Iter 154880, Minibatch Loss= 53.416435, Training Accuracy= 0.97656
# Iter 156160, Minibatch Loss= 30.187813, Training Accuracy= 0.97656
# Iter 157440, Minibatch Loss= 351.684998, Training Accuracy= 0.94531
# Iter 158720, Minibatch Loss= 378.234741, Training Accuracy= 0.96875
# Iter 160000, Minibatch Loss= 48.999146, Training Accuracy= 0.98438
# Iter 161280, Minibatch Loss= 206.798248, Training Accuracy= 0.97656
# Iter 162560, Minibatch Loss= 131.938599, Training Accuracy= 0.98438
# Iter 163840, Minibatch Loss= 91.236855, Training Accuracy= 0.97656
# Iter 165120, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 166400, Minibatch Loss= 155.693619, Training Accuracy= 0.96875
# Iter 167680, Minibatch Loss= 221.114807, Training Accuracy= 0.95312
# Iter 168960, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 170240, Minibatch Loss= 26.224525, Training Accuracy= 0.99219
# Iter 171520, Minibatch Loss= 266.728638, Training Accuracy= 0.95312
# Iter 172800, Minibatch Loss= 29.546471, Training Accuracy= 0.99219
# Iter 174080, Minibatch Loss= 193.236664, Training Accuracy= 0.96094
# Iter 175360, Minibatch Loss= 421.336121, Training Accuracy= 0.95312
# Iter 176640, Minibatch Loss= 79.514130, Training Accuracy= 0.97656
# Iter 177920, Minibatch Loss= 170.479004, Training Accuracy= 0.96875
# Iter 179200, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 180480, Minibatch Loss= 73.145271, Training Accuracy= 0.97656
# Iter 181760, Minibatch Loss= 459.006042, Training Accuracy= 0.93750
# Iter 183040, Minibatch Loss= 233.451050, Training Accuracy= 0.96875
# Iter 184320, Minibatch Loss= 114.648521, Training Accuracy= 0.96875
# Iter 185600, Minibatch Loss= 84.401909, Training Accuracy= 0.96875
# Iter 186880, Minibatch Loss= 89.564590, Training Accuracy= 0.96875
# Iter 188160, Minibatch Loss= 76.355026, Training Accuracy= 0.96875
# Iter 189440, Minibatch Loss= 76.888390, Training Accuracy= 0.96875
# Iter 190720, Minibatch Loss= 68.623161, Training Accuracy= 0.97656
# Iter 192000, Minibatch Loss= 208.352753, Training Accuracy= 0.96094
# Iter 193280, Minibatch Loss= 66.739281, Training Accuracy= 0.99219
# Iter 194560, Minibatch Loss= 163.754242, Training Accuracy= 0.94531
# Iter 195840, Minibatch Loss= 183.674652, Training Accuracy= 0.95312
# Iter 197120, Minibatch Loss= 82.569603, Training Accuracy= 0.98438
# Iter 198400, Minibatch Loss= 85.312683, Training Accuracy= 0.98438
# Iter 199680, Minibatch Loss= 241.108276, Training Accuracy= 0.96094
# Optimization Finished!
# Testing Accuracy: 0.984375
